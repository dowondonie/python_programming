# %% [markdown]
# <a href="https://colab.research.google.com/github/dowondonie/python_programming/blob/main/7%EC%A3%BC%EC%B0%A8_%EC%88%99%EC%A0%9C3(%EA%B9%80%EB%8F%84%EC%9B%90).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Introduction to Pandas Python

# %%
import pandas as pd
# pandas라는 라이브러리를 불러오고, 앞으로 pd라는 이름으로 사용하겠다는 의미

# %%
data = {'Name':['Tom', 'nick', 'krish', 'jack'],
        'Age':[20, 21, 19, 18]}
df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age
# 0    Tom   20
# 1   nick   21
# 2  krish   19
# 3   jack   18

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
csv_path = '/content/gdrive/My Drive/TopSellingAlbums.csv'
df = pd.read_csv(csv_path)

# %%
df.head()
# Out:
#             Artist                      Album  Released   Length  \
# 0  Michael Jackson                   Thriller      1982  0:42:19
# 1            AC/DC              Back in Black      1980  0:42:11
# 2       Pink Floyd  The Dark Side of the Moon      1973  0:42:49
# 3  Whitney Houston              The Bodyguard      1992  0:57:44
# 4        Meat Loaf            Bat Out of Hell      1977  0:46:33
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# 4  hard rock, progressive rock                              20.6
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating
# 0                        65  30-Nov-82        NaN    10.0
# 1                        50  25-Jul-80        NaN     9.5
# ...

# %%
df.tail()
# Out:
#             Artist                            Album  Released   Length  \
# 3  Whitney Houston                    The Bodyguard      1992  0:57:44
# 4        Meat Loaf                  Bat Out of Hell      1977  0:46:33
# 5           Eagles  Their Greatest Hits (1971-1975)      1976  0:43:08
# 6         Bee Gees             Saturday Night Fever      1977  1:15:54
# 7    Fleetwood Mac                          Rumours      1977  0:40:01
#
#                          Genre  Music Recording Sales (millions)  \
# 3               R&B, soul, pop                              27.4
# 4  hard rock, progressive rock                              20.6
# 5   rock, soft rock, folk rock                              32.2
# 6                        disco                              20.6
# 7                    soft rock                              27.9
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating
# 3                        44  17-Nov-92          Y     8.5
# ...

# %%
xlsx_path = '/content/gdrive/My Drive/TopSellingAlbums.xlsx'

# %%
df1 = pd.read_excel(xlsx_path)
df1.head()
# Out:
#             Artist                      Album  Released    Length  \
# 0  Michael Jackson                   Thriller      1982  00:42:19
# 1            AC/DC              Back in Black      1980   0:42:11
# 2       Pink Floyd  The Dark Side of the Moon      1973   0:42:49
# 3  Whitney Houston              The Bodyguard      1992   0:57:44
# 4        Meat Loaf            Bat Out of Hell      1977   0:46:33
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# 4  hard rock, progressive rock                              20.6
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating
# 0                        65 1982-11-30        NaN    10.0
# 1                        50 1980-07-25        NaN     9.5
# ...

# %%
x = df[['Genre']]
x
# Out:
#                          Genre
# 0               pop, rock, R&B
# 1                    hard rock
# 2             progressive rock
# 3               R&B, soul, pop
# 4  hard rock, progressive rock
# 5   rock, soft rock, folk rock
# 6                        disco
# 7                    soft rock

# %%
x = df[['Length']]

# %%
x
# Out:
#     Length
# 0  0:42:19
# 1  0:42:11
# 2  0:42:49
# 3  0:57:44
# 4  0:46:33
# 5  0:43:08
# 6  1:15:54
# 7  0:40:01

# %%
x = df[['Artist']]
x
# Out:
#             Artist
# 0  Michael Jackson
# 1            AC/DC
# 2       Pink Floyd
# 3  Whitney Houston
# 4        Meat Loaf
# 5           Eagles
# 6         Bee Gees
# 7    Fleetwood Mac

# %%
y = df[['Artist','Length','Genre']]
y
# Out:
#             Artist   Length                        Genre
# 0  Michael Jackson  0:42:19               pop, rock, R&B
# 1            AC/DC  0:42:11                    hard rock
# 2       Pink Floyd  0:42:49             progressive rock
# 3  Whitney Houston  0:57:44               R&B, soul, pop
# 4        Meat Loaf  0:46:33  hard rock, progressive rock
# 5           Eagles  0:43:08   rock, soft rock, folk rock
# 6         Bee Gees  1:15:54                        disco
# 7    Fleetwood Mac  0:40:01                    soft rock

# %%
csv_path = '/content/gdrive/My Drive/TopSellingAlbums.csv'
df = pd.read_csv(csv_path)

# %%
df
# Out:
#             Artist                            Album  Released   Length  \
# 0  Michael Jackson                         Thriller      1982  0:42:19
# 1            AC/DC                    Back in Black      1980  0:42:11
# 2       Pink Floyd        The Dark Side of the Moon      1973  0:42:49
# 3  Whitney Houston                    The Bodyguard      1992  0:57:44
# 4        Meat Loaf                  Bat Out of Hell      1977  0:46:33
# 5           Eagles  Their Greatest Hits (1971-1975)      1976  0:43:08
# 6         Bee Gees             Saturday Night Fever      1977  1:15:54
# 7    Fleetwood Mac                          Rumours      1977  0:40:01
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# ...

# %%
# iloc(index location)은 숫자(index 번호)로 찾기
# loc(label location)은 이름(index나 column 이름)으로 찾기

# %%
df.iloc[0, 0]
# Out:
# 'Michael Jackson'

# %%
df.iloc[1, 0]
# Out:
# 'AC/DC'

# %%
print(int(df.iloc[0, 2]))
# Out:
# 1982

# %%
df.loc[0, 'Artist']
# Out:
# 'Michael Jackson'

# %%
df.loc[1,'Artist']
# Out:
# 'AC/DC'

# %%
print(int(df.loc[0, 'Released']))
# Out:
# 1982

# %%
print(int(df.loc[1, 'Released']))
# Out:
# 1980

# %%
df.iloc[0:2, 0:3]
# Out:
#             Artist          Album  Released
# 0  Michael Jackson       Thriller      1982
# 1            AC/DC  Back in Black      1980

# %%
df.loc[0:2, 'Artist':'Released']
# Out:
#             Artist                      Album  Released
# 0  Michael Jackson                   Thriller      1982
# 1            AC/DC              Back in Black      1980
# 2       Pink Floyd  The Dark Side of the Moon      1973

# %%
for i, j in df.iterrows():
    print(i, j)
    print()

# pandas df 안에 있는 행, 열 데이터를 한줄씩 읽어오는 코드
# interrows() ☞ 행(row)을 반복(iterate)
# i(행), j(열)로 자체적으로 정의한 변수임.
# Out:
# 0 Artist                              Michael Jackson
# Album                                      Thriller
# Released                                       1982
# Length                                      0:42:19
# Genre                                pop, rock, R&B
# Music Recording Sales (millions)               46.0
# Claimed Sales (millions)                         65
# Released.1                                30-Nov-82
# Soundtrack                                      NaN
# Rating                                         10.0
# Name: 0, dtype: object
#
# 1 Artist                                      AC/DC
# Album                               Back in Black
# Released                                     1980
# Length                                    0:42:11
# Genre                                   hard rock
# Music Recording Sales (millions)             26.1
# Claimed Sales (millions)                       50
# Released.1                              25-Jul-80
# ...

# %%
filter2 = df["Claimed Sales (millions)"]>40
df.where(filter2)
# Out:
#             Artist                            Album  Released   Length  \
# 0  Michael Jackson                         Thriller    1982.0  0:42:19
# 1            AC/DC                    Back in Black    1980.0  0:42:11
# 2       Pink Floyd        The Dark Side of the Moon    1973.0  0:42:49
# 3  Whitney Houston                    The Bodyguard    1992.0  0:57:44
# 4        Meat Loaf                  Bat Out of Hell    1977.0  0:46:33
# 5           Eagles  Their Greatest Hits (1971-1975)    1976.0  0:43:08
# 6              NaN                              NaN       NaN      NaN
# 7              NaN                              NaN       NaN      NaN
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# ...

# %%
#Quiz on DataFrame

# %%
csv_path = '/content/gdrive/My Drive/TopSellingAlbums.csv'
df = pd.read_csv(csv_path)

# %%
df
# Out:
#             Artist                            Album  Released   Length  \
# 0  Michael Jackson                         Thriller      1982  0:42:19
# 1            AC/DC                    Back in Black      1980  0:42:11
# 2       Pink Floyd        The Dark Side of the Moon      1973  0:42:49
# 3  Whitney Houston                    The Bodyguard      1992  0:57:44
# 4        Meat Loaf                  Bat Out of Hell      1977  0:46:33
# 5           Eagles  Their Greatest Hits (1971-1975)      1976  0:43:08
# 6         Bee Gees             Saturday Night Fever      1977  1:15:54
# 7    Fleetwood Mac                          Rumours      1977  0:40:01
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# ...

# %%
#1. Use a variable q to store the column Rating as a dataframe

# %%
q = df[['Rating']]
q
# Out:
#    Rating
# 0    10.0
# 1     9.5
# 2     9.0
# 3     8.5
# 4     8.0
# 5     7.5
# 6     7.0
# 7     6.5

# %%
#2. Assign the variable q to the dataframe that is made up of the column Released and Artist:

# %%
q = df[['Released', 'Artist']]
q
# Out:
#    Released           Artist
# 0      1982  Michael Jackson
# 1      1980            AC/DC
# 2      1973       Pink Floyd
# 3      1992  Whitney Houston
# 4      1977        Meat Loaf
# 5      1976           Eagles
# 6      1977         Bee Gees
# 7      1977    Fleetwood Mac

# %%
#3. Access the 2nd row and the 3rd column of df:
# row는 행, column은 열 2행, 3열은 1980이 나와야  함. 근데 index는 0부터 접근하니까 각각 -1 해주면 편함

# %%
print(int(df.iloc[1,2]))
# Out:
# 1980
